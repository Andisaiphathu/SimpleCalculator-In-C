# %% [markdown]
#      1 #include <iostream>
#      2
#      3  #include <iostream>
#      4
#      5  int main() {
#      6      std::cout << "SIMPLE CALCULATOR" << std::endl;
#      7
#      8      double num1, num2;
#      9      char op;
#     10
#     11
#     12      std::cout << "Enter the Operator (+ - * /): ";
#     13      std::cin >> op;
#     14
#     15
#     16      std::cout << "Enter the two numbers one by one: ";
#     17      std::cin >> num1 >> num2;
#     18
#     19
#     20      switch (op) {
#     21          case '+':
#     22              std::cout << num1 << " + " << num2 << " = " << num1 + num2 << std::endl;
#     23              break;
#     24          case '-':
#     25              std::cout << num1 << " - " << num2 << " = " << num1 - num2 << std::endl;
#     26              break;
#     27          case '*':
#     28              std::cout << num1 << " * " << num2 << " = " << num1 * num2 << std::endl;
#     29              break;
#     30          case '/':
#     31              if (num2 == 0.0) {
#     32                  std::cout << "Divide by Zero Situation" << std::endl;
#     33              } else {
#     34                  std::cout << num1 << " / " << num2 << " = " << num1 / num2 << std::endl;
#     35              }
#     36              break;
#     37          default:
#     38              std::cout << "Invalid Operator" << std::endl;
#     39              break;
#     40      }
#     41
#     42      return 0;
#     43  }
